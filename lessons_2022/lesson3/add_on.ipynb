# %%
from scipy.optimize import minimize

V_tv = [5,4,6,3]
V_np = [2,3,7,7]
target = 9

def obj(x): 
  val = 0
  for i in range(4):
    val += (V_tv[i]*x[0] + V_np[i]*x[1] - target)**2
  return val

def constraint(x):
  return np.sum(x) - 1

constraints = {'type':'eq', 'fun':constraint}

bounds = [(0.0, 10), (0.0, 10.0)]
r = minimize(obj, [0.1, 0.1], bounds=bounds)#, constraints=constraints)
print (r)
# Out:
#       fun: 14.44808272296427
#  hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#       jac: array([3.01980665e-06, 3.90798505e-06])
#   message: 'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 18
#       nit: 3
#      njev: 6
#    status: 0
#   success: True
#         x: array([1.48513574, 0.40327444])
